# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Numpy" data-toc-modified-id="Numpy-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Numpy</a></span><ul class="toc-item"><li><span><a href="#Randomization" data-toc-modified-id="Randomization-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Randomization</a></span></li><li><span><a href="#Operations" data-toc-modified-id="Operations-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Operations</a></span></li><li><span><a href="#Norm" data-toc-modified-id="Norm-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Norm</a></span></li><li><span><a href="#Neural-Network" data-toc-modified-id="Neural-Network-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>Neural Network</a></span></li><li><span><a href="#Scalar-function" data-toc-modified-id="Scalar-function-1.5"><span class="toc-item-num">1.5&nbsp;&nbsp;</span>Scalar function</a></span></li><li><span><a href="#Vector-function" data-toc-modified-id="Vector-function-1.6"><span class="toc-item-num">1.6&nbsp;&nbsp;</span>Vector function</a></span></li><li><span><a href="#Debugging-exercise" data-toc-modified-id="Debugging-exercise-1.7"><span class="toc-item-num">1.7&nbsp;&nbsp;</span>Debugging exercise</a></span></li></ul></li></ul></div>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import jupyterthemes.jtplot as jtplot
# %matplotlib inline
jtplot.style(theme='onedork')

# %% [markdown]
# ## Numpy

# %% [markdown]
# ### Randomization

# %%
def randomization(n):
    """
    Arg:
      n - an integer
    Returns:
      A - a randomly-generated nx1 Numpy array.
    """
    #Your code here
    A = np.random.random((n,1))
    return A
    raise NotImplementedError

# %% [markdown]
# ### Operations

# %%
def operations(h, w):
    """
    Takes two inputs, h and w, and makes two Numpy arrays A and B of size
    h x w, and returns A, B, and s, the sum of A and B.

    Arg:
      h - an integer describing the height of A and B
      w - an integer describing the width of A and B
    Returns (in this order):
      A - a randomly-generated h x w Numpy array.
      B - a randomly-generated h x w Numpy array.
      s - the sum of A and B.
    """
    #Your code here
    A = np.random.random((h,w))
    B = np.random.random((h,w))
    s = A+B
    return A,B,s
    raise NotImplementedError

# %%
A,B,s = operations(2,1)

# %% [markdown]
# ### Norm

# %%
def norm(A, B):
    """
    Takes two Numpy column arrays, A and B, and returns the L2 norm of their
    sum.

    Arg:
      A - a Numpy array
      B - a Numpy array
    Returns:
      s - the L2 norm of A+B.
    """
    #Your code here
    
    try:
        s = np.linalg.norm(A+B)
        return s
    except:
        raise NotImplementedError

# %%
norm(A,B)
# Out:
# 1.3934755523145608

# %% [markdown]
# ### Neural Network

# %%
def neural_network(inputs, weights):
    """
     Takes an input vector and runs it through a 1-layer neural network
     with a given weight matrix and returns the output.

     Arg:
       inputs - 2 x 1 NumPy array
       weights - 2 x 1 NumPy array
     Returns (in this order):
       out - a 1 x 1 NumPy array, representing the output of the neural network
    """
    #Your code here
    try:
        out = np.tanh(np.matmul(np.transpose(weights),inputs))
        return out
    except:
        raise NotImplementedError

# %%
neural_network(A,B).shape
# Out:
# (1, 1)

# %% [markdown]
# ### Scalar function

# %%
def scalar_function(x, y):
    """
    Returns the f(x,y) defined in the problem statement.
    """
    #Your code here
    try:
        if x<=y:
            return x*y
        else:
            return x/y
    except:
        raise NotImplementedError

# %%
scalar_function(1,2)
# Out:
# 2

# %% [markdown]
# ### Vector function

# %%
def vector_function(x, y):
    """
    Make sure vector_function can deal with vector input x,y 
    """
    #Your code here
    try:
        return np.vectorize(scalar_function)(x,y)
    except:
        raise NotImplementedError

# %%
vector_function([1,2,4],3)
# Out:
# array([3, 6, 1])

# %% [markdown]
# ### Debugging exercise
# - pdb

# %%
def get_sum_metrics(predictions, metrics=None):
    if metrics is None:
        metrics=[]
    else:
        metrics=metrics
    for i in range(3):
        m=lambda x,j=i: x + j
        metrics.append(m)

    sum_metrics = 0
    for metric in metrics:
#         print('00',metric(predictions))
        sum_metrics += metric(predictions)

    return sum_metrics

# %%
for c in range(3):
    print(get_sum_metrics(c))
# Out:
# 00 0
# 00 1
# 00 2
# 3
# 00 1
# 00 2
# 00 3
# 6
# 00 2
# 00 3
# 00 4
# 9

# %%
s=0
predictions=
metrics=[lambda x:x]
for i in range(3):
    m=lambda x,j=i: x+j
    metrics.append(m)
for m in metrics:
    print(m(predictions))
    s+=m(predictions)
print(s)
# Out:
# 3
# 3
# 4
# 5
# 15
